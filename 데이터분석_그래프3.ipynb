# %% [markdown]
# <a href="https://colab.research.google.com/github/ChaeHyunIM/Helloworld/blob/main/%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D_%EA%B7%B8%EB%9E%98%ED%94%843.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d4=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Source/rent_total_2019.csv', header=0, encoding='cp949', thousands=',')
d4
# Out:
#      자치구  201901  201902  201903  ...  201910  201911  201912      총합계
# 0    강남구   19773   18740   39697  ...   99586   63257   33083   803529
# 1    강동구   15268   14394   27385  ...   90625   56429   31262   667738
# 2    강북구    8030    7583   15217  ...   42329   27120   16050   335262
# 3    강서구   23154   21856   43734  ...  162574  103627   60615  1168633
# 4    관악구   18592   16387   32914  ...   80316   50730   29547   678042
# 5    광진구   29205   27194   57886  ...  149523   94554   54581  1193807
# 6    구로구   16888   15668   29303  ...   90733   58204   33135   680547
# 7    금천구    8206    7197   13739  ...   37360   25142   15082   292707
# 8    노원구   21789   21286   42348  ...  120477   77245   44917   937319
# 9    도봉구    6497    6808   14006  ...   41170   26149   14484   314399
# 10  동대문구   16978   15553   31944  ...   84796   56442   33709   663319
# 11   동작구   11244   11057   21942  ...   63418   38062   20174   474601
# ...

# %%
d5=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Source/dep_total_2019.csv', header=0, encoding='cp949', thousands=',')

# %%
d5
# Out:
#      자치구  201901  201902  201903  ...  201909  201910  201911  201912
# 0    강남구    1210    1210    1210  ...    1210    1210    1218    1218
# 1    강동구     773     773     773  ...     773     773     763     763
# 2    강북구     451     451     451  ...     451     451     451     451
# 3    강서구    1014    1014    1014  ...    1014    1014    1002    1002
# 4    관악구     652     652     652  ...     652     652     640     640
# 5    광진구     793     793     793  ...     793     793     841     841
# 6    구로구     728     728     728  ...     728     728     788     788
# 7    금천구     540     540     540  ...     540     540     560     560
# 8    노원구     850     850     850  ...     850     850     879     879
# 9    도봉구     423     423     423  ...     423     423     396     396
# 10  동대문구     653     653     653  ...     653     653     659     659
# 11   동작구     501     501     501  ...     501     501     501     501
# ...

# %%
d6=pd.merge(d4,d5, on='자치구')

# %%
d6
# Out:
#      자치구  201901_x  201902_x  201903_x  ...  201909_y  201910_y  201911_y  201912_y
# 0    강남구     19773     18740     39697  ...      1210      1210      1218      1218
# 1    강동구     15268     14394     27385  ...       773       773       763       763
# 2    강북구      8030      7583     15217  ...       451       451       451       451
# 3    강서구     23154     21856     43734  ...      1014      1014      1002      1002
# 4    관악구     18592     16387     32914  ...       652       652       640       640
# 5    광진구     29205     27194     57886  ...       793       793       841       841
# 6    구로구     16888     15668     29303  ...       728       728       788       788
# 7    금천구      8206      7197     13739  ...       540       540       560       560
# 8    노원구     21789     21286     42348  ...       850       850       879       879
# 9    도봉구      6497      6808     14006  ...       423       423       396       396
# ...

# %%
강남구_1월=d6['201901_x']/d6['201901_y']

# %%
강남구_1월
# Out:
# 0     16.341322
# 1     19.751617
# 2     17.804878
# 3     22.834320
# 4     28.515337
# 5     36.828499
# 6     23.197802
# 7     15.196296
# 8     25.634118
# 9     15.359338
# 10    26.000000
# 11    22.443114
# 12    33.761770
# 13    24.837410
# 14    16.224876
# 15    30.998718
# 16    21.869382
# 17    26.211884
# 18    20.776772
# 19    32.363275
# 20    16.514337
# 21    21.779070
# 22    41.525874
# 23    34.146237
# 24    19.277597
# dtype: float64

# %%
구_월=[]
for i in range(1,9+1):
  ym1 = '20190' + str(i) + '_x'
  ym2 = '20190' + str(i) + '_y'
  구_월.append(d6[ym1]/d6[ym2])
구_월
# Out:
# [0     16.341322
#  1     19.751617
#  2     17.804878
#  3     22.834320
#  4     28.515337
#  5     36.828499
#  6     23.197802
#  7     15.196296
#  8     25.634118
#  9     15.359338
#  10    26.000000
#  11    22.443114
#  12    33.761770
#  13    24.837410
#  14    16.224876
#  15    30.998718
#  16    21.869382
#  17    26.211884
#  18    20.776772
#  19    32.363275
#  20    16.514337
#  21    21.779070
#  22    41.525874
#  23    34.146237
#  24    19.277597
#  dtype: float64, 0     15.487603
#  1     18.620957
#  2     16.813747
#  3     21.554241
#  4     25.133436
#  5     34.292560
#  6     21.521978
#  7     13.327778
#  8     25.042353
#  9     16.094563
#  10    23.817764
#  11    22.069860
#  12    31.143126
#  13    22.482014
#  14    15.525535
#  15    28.903846
#  16    20.160112
#  17    26.312744
#  18    18.674208
#  19    28.328299
#  20    16.526882
#  21    20.906977
#  22    36.019580
#  23    29.763441
#  24    17.892857
# ...

# %%
type(구_월)
# Out:
# list

# %%
d8=pd.DataFrame(구_월)

# %%
d8
# Out:
#           0           1          2   ...          22          23         24
# 0  16.341322   19.751617  17.804878  ...   41.525874   34.146237  19.277597
# 1  15.487603   18.620957  16.813747  ...   36.019580   29.763441  17.892857
# 2  32.807438   35.426908  33.740576  ...   63.655944   54.077419  34.834416
# 3  55.384298   55.622251  52.645233  ...   91.958042   78.393548  52.155844
# 4  80.504132   94.800776  84.623060  ...  118.446154  105.073118  86.452922
# 5  83.077686  104.664942  92.605322  ...  118.713287  107.683871  94.613636
# 6  75.906612  102.309185  86.831486  ...  118.391608  107.365591  90.629870
# 7  71.374380  101.483829  84.731707  ...  109.274126   98.737634  89.144481
# 8  71.267769  100.465718  84.002217  ...  111.255944   98.967742  91.256494
#
# [9 rows x 25 columns]

# %%
구_월1=[]
for i in range(10,12+1):
  ym1 = '2019' + str(i) + '_x'
  ym2 = '2019' + str(i) + '_y'
  구_월1.append(d6[ym1]/d6[ym2])
구_월1
# Out:
# [0      82.302479
#  1     117.238034
#  2      93.855876
#  3     160.329389
#  4     123.184049
#  5     188.553594
#  6     124.633242
#  7      69.185185
#  8     141.737647
#  9      97.328605
#  10    129.856049
#  11    126.582834
#  12    162.924670
#  13     95.671942
#  14     89.942339
#  15    146.292308
#  16    113.845506
#  17    168.050039
#  18    112.164404
#  19    157.532591
#  20     93.250896
#  21    104.966570
#  22    134.406993
#  23    121.729032
#  24    105.512987
#  dtype: float64, 0      51.935140
#  1      73.956750
#  2      60.133038
#  3     103.420160
#  4      79.265625
#  5     112.430440
#  6      73.862944
#  7      44.896429
#  8      87.878271
#  9      66.032828
#  10     85.647951
#  11     75.972056
#  12     96.603721
#  13     68.019490
#  14     52.746536
#  15     93.144872
#  16     69.720386
#  17     96.604006
#  18     69.912851
#  19     97.586645
#  20     53.672862
#  21     64.756983
#  22     91.619898
#  23     80.693712
# ...

# %%
d9=pd.DataFrame(구_월1, index=['10','11','12'])

# %%
d9
# Out:
#            0           1          2   ...          22          23          24
# 10  82.302479  117.238034  93.855876  ...  134.406993  121.729032  105.512987
# 11  51.935140   73.956750  60.133038  ...   91.619898   80.693712   65.912338
# 12  27.161741   40.972477  35.587583  ...   57.440051   50.316430   37.430195
#
# [3 rows x 25 columns]

# %%
d10=pd.concat([d8,d9])

# %%
d10
# Out:
#            0           1          2   ...          22          23          24
# 0   16.341322   19.751617  17.804878  ...   41.525874   34.146237   19.277597
# 1   15.487603   18.620957  16.813747  ...   36.019580   29.763441   17.892857
# 2   32.807438   35.426908  33.740576  ...   63.655944   54.077419   34.834416
# 3   55.384298   55.622251  52.645233  ...   91.958042   78.393548   52.155844
# 4   80.504132   94.800776  84.623060  ...  118.446154  105.073118   86.452922
# 5   83.077686  104.664942  92.605322  ...  118.713287  107.683871   94.613636
# 6   75.906612  102.309185  86.831486  ...  118.391608  107.365591   90.629870
# 7   71.374380  101.483829  84.731707  ...  109.274126   98.737634   89.144481
# 8   71.267769  100.465718  84.002217  ...  111.255944   98.967742   91.256494
# 10  82.302479  117.238034  93.855876  ...  134.406993  121.729032  105.512987
# 11  51.935140   73.956750  60.133038  ...   91.619898   80.693712   65.912338
# ...

# %%
d11=d10.rename(columns={0:'강남구',1:'강동구',2:'강북구',3:'강서구',4:'관악구',5:'광진구',6:'구로구',7:'금천구',8:'노원구',9:'도봉구',10:'동대문구',11:'동작구',12:'마포구',13:'서대문구',14:'서초구',15:'성동구',16:'성북구',17:'송파구',18:'양천구',19:'영등포구',20:'용산구',21:'은평구',22:'종로구',23:'중구',24:'중랑구'})

# %%
d11
# Out:
#           강남구         강동구        강북구  ...         종로구          중구         중랑구
# 0   16.341322   19.751617  17.804878  ...   41.525874   34.146237   19.277597
# 1   15.487603   18.620957  16.813747  ...   36.019580   29.763441   17.892857
# 2   32.807438   35.426908  33.740576  ...   63.655944   54.077419   34.834416
# 3   55.384298   55.622251  52.645233  ...   91.958042   78.393548   52.155844
# 4   80.504132   94.800776  84.623060  ...  118.446154  105.073118   86.452922
# 5   83.077686  104.664942  92.605322  ...  118.713287  107.683871   94.613636
# 6   75.906612  102.309185  86.831486  ...  118.391608  107.365591   90.629870
# 7   71.374380  101.483829  84.731707  ...  109.274126   98.737634   89.144481
# 8   71.267769  100.465718  84.002217  ...  111.255944   98.967742   91.256494
# 10  82.302479  117.238034  93.855876  ...  134.406993  121.729032  105.512987
# 11  51.935140   73.956750  60.133038  ...   91.619898   80.693712   65.912338
# ...

# %%
pd.DataFrame(d11.mean(), columns=['평균'])
# Out:
#               평균
# 강남구    55.295883
# 강동구    72.109454
# 강북구    61.947894
# 강서구    96.203153
# 관악구    86.854191
# 광진구   124.558127
# 구로구    77.105340
# 금천구    44.949140
# 노원구    91.498885
# 도봉구    62.484128
# 동대문구   84.545457
# 동작구    78.942282
# 마포구   105.247649
# 서대문구   68.630300
# 서초구    58.409980
# 성동구    96.111218
# 성북구    72.133370
# 송파구   103.018726
# 양천구    69.007119
# 영등포구  102.709791
# 용산구    58.300034
# 은평구    67.159864
# 종로구    91.058958
# 중구     80.578981
# 중랑구    65.426136

# %%
d20=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Source/rent_total_2020.csv', header=0, encoding='cp949', thousands=',')

# %%
d21=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Source/dep_total_2020.csv', header=0, encoding='cp949', thousands=',')

# %%
d22=pd.merge(d20,d21, on='자치구')

# %%
d22
# Out:
#      자치구  202001_x  202002_x  202003_x  ...  202009_y  202010_y  202011_y  202012_y
# 0    강남구     31431     28331     62298  ...      1442      1482      1477      1487
# 1    강동구     28792     27770     56628  ...      1112      1162      1177      1197
# 2    강북구     14683     14242     28364  ...       641       651       676       676
# 3    강서구     55764     55341     97810  ...      1741      1726      1941      2020
# 4    관악구     27351     25933     43517  ...       834       843       828       828
# 5    광진구     46804     44635     92565  ...      1030      1026      1029      1136
# 6    구로구     29983     28625     49774  ...      1141      1136      1184      1184
# 7    금천구     13567     13702     22246  ...       717       717       717       717
# 8    노원구     40903     38809     73885  ...      1150      1193      1171      1171
# 9    도봉구     13306     13388     27421  ...       666       673       673       673
# ...

# %%
구_월2=[]
for i in range(1,9+1):
  ym1 = '20200' + str(i) + '_x'
  ym2 = '20200' + str(i) + '_y'
  구_월2.append(d22[ym1]/d22[ym2])
d23=pd.DataFrame(구_월2)
d23
# Out:
#           0           1           2   ...          22         23          24
# 0  25.805419   37.735256   32.556541  ...   49.830357  43.133874   33.693182
# 1  22.810789   36.443570   31.648889  ...   39.335202  29.442598   31.982143
# 2  51.147783   74.217562   62.891353  ...   70.262755  64.576065   63.923701
# 3  64.918719  105.195282   89.953437  ...   97.177296  92.679513   97.612013
# 4  70.021346  128.967235  102.942350  ...  100.744898  96.505071  118.639610
# 5  64.427878  100.447842   84.522621  ...   80.826667  68.520497   91.243275
# 6  54.919556   87.876799   85.028081  ...   76.386667  65.114286   89.872515
# 7  34.014563   54.423561   53.482059  ...   58.425778  50.187578   59.132164
# 8  61.520804   93.133094   84.808112  ...   78.412444  69.255901   95.119298
#
# [9 rows x 25 columns]

# %%
구_월2=[]
for i in range(10,12+1):
  ym1 = '2020' + str(i) + '_x'
  ym2 = '2020' + str(i) + '_y'
  구_월2.append(d22[ym1]/d22[ym2])
구_월2
d24=pd.DataFrame(구_월2, index=['10','11','12'])
d24
# Out:
#            0          1         2   ...         22         23          24
# 10  60.750337  88.922547  86.40553  ...  90.459184  73.169143  101.211976
# 11  42.457007  57.426508  60.22929  ...  74.545151  48.437148   70.844578
# 12  25.557498  35.399332  36.08284  ...  41.708059  27.913761   40.216867
#
# [3 rows x 25 columns]

# %%
d25=pd.concat([d23,d24])
d25
# Out:
#            0           1           2   ...          22         23          24
# 0   25.805419   37.735256   32.556541  ...   49.830357  43.133874   33.693182
# 1   22.810789   36.443570   31.648889  ...   39.335202  29.442598   31.982143
# 2   51.147783   74.217562   62.891353  ...   70.262755  64.576065   63.923701
# 3   64.918719  105.195282   89.953437  ...   97.177296  92.679513   97.612013
# 4   70.021346  128.967235  102.942350  ...  100.744898  96.505071  118.639610
# 5   64.427878  100.447842   84.522621  ...   80.826667  68.520497   91.243275
# 6   54.919556   87.876799   85.028081  ...   76.386667  65.114286   89.872515
# 7   34.014563   54.423561   53.482059  ...   58.425778  50.187578   59.132164
# 8   61.520804   93.133094   84.808112  ...   78.412444  69.255901   95.119298
# 10  60.750337   88.922547   86.405530  ...   90.459184  73.169143  101.211976
# 11  42.457007   57.426508   60.229290  ...   74.545151  48.437148   70.844578
# ...

# %%
d26=d25.rename(columns={0:'강남구',1:'강동구',2:'강북구',3:'강서구',4:'관악구',5:'광진구',6:'구로구',7:'금천구',8:'노원구',9:'도봉구',10:'동대문구',11:'동작구',12:'마포구',13:'서대문구',14:'서초구',15:'성동구',16:'성북구',17:'송파구',18:'양천구',19:'영등포구',20:'용산구',21:'은평구',22:'종로구',23:'중구',24:'중랑구'})
d26
# Out:
#           강남구         강동구         강북구  ...         종로구         중구         중랑구
# 0   25.805419   37.735256   32.556541  ...   49.830357  43.133874   33.693182
# 1   22.810789   36.443570   31.648889  ...   39.335202  29.442598   31.982143
# 2   51.147783   74.217562   62.891353  ...   70.262755  64.576065   63.923701
# 3   64.918719  105.195282   89.953437  ...   97.177296  92.679513   97.612013
# 4   70.021346  128.967235  102.942350  ...  100.744898  96.505071  118.639610
# 5   64.427878  100.447842   84.522621  ...   80.826667  68.520497   91.243275
# 6   54.919556   87.876799   85.028081  ...   76.386667  65.114286   89.872515
# 7   34.014563   54.423561   53.482059  ...   58.425778  50.187578   59.132164
# 8   61.520804   93.133094   84.808112  ...   78.412444  69.255901   95.119298
# 10  60.750337   88.922547   86.405530  ...   90.459184  73.169143  101.211976
# 11  42.457007   57.426508   60.229290  ...   74.545151  48.437148   70.844578
# ...

# %%
d27=pd.DataFrame(d26.mean(), columns=['평균'])
d27
# Out:
#               평균
# 강남구    48.195975
# 강동구    75.015715
# 강북구    67.545925
# 강서구   113.047700
# 관악구    88.949963
# 광진구   104.655443
# 구로구    77.587802
# 금천구    51.335947
# 노원구   101.851200
# 도봉구    71.461594
# 동대문구   86.666234
# 동작구    72.120818
# 마포구   103.412561
# 서대문구   61.281036
# 서초구    53.040190
# 성동구    99.566850
# 성북구    74.800094
# 송파구    94.385928
# 양천구    96.378755
# 영등포구  117.255033
# 용산구    63.619144
# 은평구    73.183777
# 종로구    71.509538
# 중구     60.744620
# 중랑구    74.457610

# %%
type(d26.mean())
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### d11,d12 (2019)
# ### d26,d27 (2020) 정제된 데이터값

# %%
np.array(d26.mean())
list(np.array(d26.mean()))
# Out:
# [48.195975126197546,
#  75.01571548257961,
#  67.54592528040003,
#  113.04769974963716,
#  88.94996278118333,
#  104.6554433966591,
#  77.58780232926217,
#  51.33594715082685,
#  101.85120027403225,
#  71.46159387329236,
#  86.66623439916238,
#  72.12081752913848,
#  103.41256108833782,
#  61.28103571302912,
#  53.04018983666186,
#  99.56685031586822,
#  74.80009430965369,
#  94.38592786218754,
#  96.37875535905903,
#  117.25503323240527,
#  63.61914366137794,
#  73.18377681808012,
#  71.50953807144954,
#  60.74461957717643,
#  74.4576102203062]

# %%
# %matplotlib inline  

import matplotlib as mpl 
import matplotlib.pyplot as plt 
import matplotlib.font_manager as fm  

# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf' 
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

fm._rebuild()
mpl.rcParams['axes.unicode_minus'] = False
# Out:
# NanumBarunGothic

# %%
labels = ['강남구','강동구','강북구','강서구','관악구','광진구','구로구','금천구','노원구','도봉구','동대문구','동작구','마포구','서대문구','서초구','성동구','성북구','송파구','양천구','영등포구','용산구','은평구','종로구','중구','중랑구']
means_1 = list(np.array(d11.mean()))
means_2 = list(np.array(d26.mean()))

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, means_1, width, label='2019')
rects2 = ax.bar(x + width/2, means_2, width, label='2020')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('월별 대여건수/배차수의 평균')
ax.set_title('구별 코로나 이후 평균대여건수/배차수 차이')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
plt.rc('figure', figsize=(20, 4))

fig.tight_layout()

plt.show()

# %%
np.array(d11.mean())-np.array(d26.mean())
# Out:
# array([  7.09990814,  -2.90626181,  -5.59803171, -16.84454639,
#         -2.09577135,  19.90268325,  -0.48246192,  -6.38680694,
#        -10.35231529,  -8.97746625,  -2.1207773 ,   6.82146457,
#          1.83508837,   7.34926442,   5.36978976,  -3.45563237,
#         -2.66672474,   8.63279774, -27.37163626, -14.54524256,
#         -5.31910935,  -6.02391272,  19.54942038,  19.83436179,
#         -9.03147386])

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = ['강남구','강동구','강북구','강서구','관악구','광진구','구로구','금천구','노원구','도봉구','동대문구','동작구','마포구','서대문구','서초구','성동구','성북구','송파구','양천구','영등포구','용산구','은평구','종로구','중구','중랑구']
dif = list(np.array(d11.mean())-np.array(d26.mean()))

 = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, dif, width, label='차이')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('연간 대여건수/배차수의 평균차')
ax.set_title('구별 코로나 이후 평균대여건수/배차수 차이')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
plt.rc('figure', figsize=(20, 4))

fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt

y_axis = ['강남구','강동구','강북구','강서구','관악구','광진구','구로구','금천구','노원구','도봉구','동대문구','동작구','마포구','서대문구','서초구','성동구','성북구','송파구','양천구','영등포구','용산구','은평구','종로구','중구','중랑구']
x_axis = list(np.array(d11.mean())-np.array(d26.mean()))

plt.barh(y_axis,x_axis)
plt.title('구별 코로나 이후 평균대여건수/배차수 차이')
plt.ylabel('자치구')
plt.xlabel('연간 대여건수/배차수의 평균차')
plt.rc('figure', figsize=(10, 20))
fig.tight_layout()
plt.show()

# %% [markdown]
# ##위의 그래프 3개가 그래프3을 나타냅니다.

# %%
import requests
import json
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize
import os
import webbrowser
import folium
from folium import plugins
print(folium.__version__)
# Out:
# 0.8.3

# %%
geo_data = 'https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json'

# %%
center = [37.541, 126.986]

# %%
dp=pd.DataFrame(list(np.array(d11.mean())-np.array(d26.mean())), columns=['차이'])

# %%
dp = df.assign(구 = ['강남구','강동구','강북구','강서구','관악구','광진구','구로구','금천구','노원구','도봉구','동대문구','동작구','마포구','서대문구','서초구','성동구','성북구','송파구','양천구','영등포구','용산구','은평구','종로구','중구','중랑구'])

# %%
dp
# Out:
#        구         차이
# 0    강남구   7.099908
# 1    강동구  -2.906262
# 2    강북구  -5.598032
# 3    강서구 -16.844546
# 4    관악구  -2.095771
# 5    광진구  19.902683
# 6    구로구  -0.482462
# 7    금천구  -6.386807
# 8    노원구 -10.352315
# 9    도봉구  -8.977466
# 10  동대문구  -2.120777
# 11   동작구   6.821465
# 12   마포구   1.835088
# 13  서대문구   7.349264
# 14   서초구   5.369790
# 15   성동구  -3.455632
# 16   성북구  -2.666725
# 17   송파구   8.632798
# 18   양천구 -27.371636
# 19  영등포구 -14.545243
# 20   용산구  -5.319109
# 21   은평구  -6.023913
# 22   종로구  19.549420
# 23    중구  19.834362
# 24   중랑구  -9.031474

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Source/dataz.csv')
df
# Out:
#        구         차이
# 0    강남구   7.099908
# 1    강동구  -2.906262
# 2    강북구  -5.598032
# 3    강서구 -16.844546
# 4    관악구  -2.095771
# 5    광진구  19.902683
# 6    구로구  -0.482462
# 7    금천구  -6.386807
# 8    노원구 -10.352315
# 9    도봉구  -8.977466
# 10  동대문구  -2.120777
# 11   동작구   6.821465
# 12   마포구   1.835088
# 13  서대문구   7.349264
# 14   서초구   5.369790
# 15   성동구  -3.455632
# 16   성북구  -2.666725
# 17   송파구   8.632798
# 18   양천구 -27.371636
# 19  영등포구 -14.545243
# 20   용산구  -5.319109
# 21   은평구  -6.023913
# 22   종로구  19.549420
# 23    중구  19.834362
# 24   중랑구  -9.031474

# %%
state_geo = 'https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json'

# %%
center = [37.541, 126.986]

# 맵이 center 에 위치하고, zoom 레벨은 11로 시작하는 맵 m을 만듭니다.
m = folium.Map(location=center, zoom_start=10, tiles='Stamenwatercolor')

# Choropleth 레이어를 만들고, 맵 m에 추가합니다.
folium.Choropleth(
    geo_path=geo_data,
    data=df,
    columns=['구', '차이'],
    key_on='feature.properties.구',
    fill_color='YlGn',
    legend_name='연평균이용량차이',
).add_to(m)
m
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-171-b66d1c73538f> in <module>()
#      11     key_on='feature.properties.구',
#      12     fill_color='YlGn',
# ---> 13     legend_name='연평균이용량차이',
#      14 ).add_to(m)
#      15 m
#
# TypeError: __init__() missing 1 required positional argument: 'geo_data'

# %%
m = folium.Map(location=[37.562225, 126.978555], tiles="cartodbpositron", zoom_start=11)

m.choropleth(
    geo_data=state_geo,
    name='구별 연평균이용량',
    data=dp,
    columns=['구', '차이'],
    key_on='feature.properties.name',
    fill_color='PuRd',
    color = 'red',
    line_opacitiy=0.9,
    legend_name = '연간평균이용량차이')
m
# Out:
# /usr/local/lib/python3.7/dist-packages/folium/folium.py:426: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# ...
